# %% [markdown]
# # Introduction

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
plt.switch_backend('Agg')
# %matplotlib inline
import seaborn as sns
import warnings
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, IsolationForest
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy import stats

# %% [markdown]
# # Overview

# %%
# Load dataset
path = r'..\Datasets\steamcharts.csv'
df = pd.read_csv(path)
df
# Out:
#          month  avg_players     gain  gain_percent  peak_players  \
# 0       Sep-25      7805.25   883.12        0.1276         13254
# 1       Aug-25      6922.13  -449.35       -0.0610         12168
# 2       Jul-25      7371.48   -833.5       -0.1016         13951
# 3       Jun-25      8204.98  -847.53       -0.0936         15798
# 4       May-25      9052.51  -471.31       -0.0495         15333
# ...        ...          ...      ...           ...           ...
# 612260  Apr-25         2.48    -0.92       -0.2709             8
# 612261  Mar-25         3.40    -0.19       -0.0532            11
# 612262  Feb-25         3.59    -0.65       -0.1527            12
# 612263  Jan-25         4.23    -0.53       -0.1119            11
# 612264  Dec-24         4.77     0.78        0.1950            13
#
#                                         name  steam_appid
# 0                             Counter-Strike           10
# 1                             Counter-Strike           10
# 2                             Counter-Strike           10
# 3                             Counter-Strike           10
# 4                             Counter-Strike           10
# ...                                      ...          ...
# 612260  The Ditzy Demons Are in Love With Me       802870
# 612261  The Ditzy Demons Are in Love With Me       802870
# 612262  The Ditzy Demons Are in Love With Me       802870
# 612263  The Ditzy Demons Are in Love With Me       802870
# 612264  The Ditzy Demons Are in Love With Me       802870
#
# [612265 rows x 7 columns]

# %%
# Data with few rows
df.head()
# Out:
#     month  avg_players     gain  gain_percent  peak_players            name  \
# 0  Sep-25      7805.25   883.12        0.1276         13254  Counter-Strike
# 1  Aug-25      6922.13  -449.35       -0.0610         12168  Counter-Strike
# 2  Jul-25      7371.48   -833.5       -0.1016         13951  Counter-Strike
# 3  Jun-25      8204.98  -847.53       -0.0936         15798  Counter-Strike
# 4  May-25      9052.51  -471.31       -0.0495         15333  Counter-Strike
#
#    steam_appid
# 0           10
# 1           10
# 2           10
# 3           10
# 4           10

# %%
# Data info to check type data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612265 entries, 0 to 612264
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   month         612265 non-null  object
#  1   avg_players   612265 non-null  float64
#  2   gain          612265 non-null  object
#  3   gain_percent  612265 non-null  float64
#  4   peak_players  612265 non-null  int64
#  5   name          612265 non-null  object
#  6   steam_appid   612265 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 32.7+ MB

# %%
# Statistic Data
df.describe(include='all')
# Out:
#          month   avg_players    gain  gain_percent  peak_players  \
# count   612265  6.122650e+05  612265  6.122650e+05  6.122650e+05
# unique     159           NaN   54046           NaN           NaN
# top     Apr-19           NaN       -           NaN           NaN
# freq      6029           NaN    6728           NaN           NaN
# mean       NaN  5.932944e+02     NaN  1.471370e+01  1.192778e+03
# std        NaN  1.122613e+04     NaN  3.085757e+03  2.105437e+04
# min        NaN  0.000000e+00     NaN -1.000000e+00  0.000000e+00
# 25%        NaN  2.530000e+00     NaN -1.744000e-01  1.000000e+01
# 50%        NaN  1.061000e+01     NaN -2.040000e-02  3.200000e+01
# 75%        NaN  6.046000e+01     NaN  1.531000e-01  1.620000e+02
# max        NaN  1.584887e+06     NaN  1.622960e+06  3.236027e+06
#
#                       name    steam_appid
# count               612265  612265.000000
# unique                6725            NaN
# top     Fallout: New Vegas            NaN
# freq                   318            NaN
# mean                   NaN  346921.739786
# std                    NaN  214347.204931
# min                    NaN      10.000000
# 25%                    NaN  221260.000000
# 50%                    NaN  336610.000000
# 75%                    NaN  502800.000000
# max                    NaN  802870.000000

# %% [markdown]
# # Data cleaning and preprocessing

# %%
# Convert 'month' columns to datetime types
df['date'] = pd.to_datetime(df['month'], format='%b-%y', errors='coerce')
df['year'] = df['date'].dt.year
df['month_num'] = df['date'].dt.month
# Convert numeric columns to numeric type
numeric_col = df.drop(columns=['month','name']).columns
for col in numeric_col:
    df[col] = pd.to_numeric(df[col], errors='coerce')
# Check data types after convert
# sort by game and date
df = df.sort_values(['steam_appid', 'date'])
print(f"Loaded {len(df):,} records")
# Out:
# Loaded 612,265 records

# %% [markdown]
# # 1. Clustering

# %% [markdown]
# ## Feature Engineering for Clustering

# %%
def calculate_trajectory_features(group):
    if len(group) < 3:
        return None
    features = {
        'mean_players': group['avg_players'].mean(),
        'max_players': group['avg_players'].max(),
        'min_players': group['avg_players'].min(),
        'std_players': group['avg_players'].std(),
        'cv': group['avg_players'].std() / (group['avg_players'].mean() + 1),  # coefficient of variation
        'total_months': len(group),
        'growth_rate': group['gain_percent'].mean(),
        'peak_to_mean_ratio': group['avg_players'].max() / (group['avg_players'].mean() + 1),
        'months_declining': (group['gain'] < 0).sum() / len(group),
        'final_to_peak_ratio': group['avg_players'].iloc[-1] / (group['avg_players'].max() + 1)
    }
    return pd.Series(features)
game_features = df.groupby('name').apply(calculate_trajectory_features).dropna()
print(f"Created features for {len(game_features)} games")
game_features.head()
# Out:
# Created features for 6660 games
#                                            mean_players  max_players  \
# name
#  Chinese PaladinSword and Fairy 5 Prequel     59.126082       141.63
#  Fieldrunners 2                               13.705948       253.91
# #KILLALLZOMBIES                                6.455750       106.23
# #monstercakes                                 38.441961       134.36
# (Chinese PaladinSword and Fairy 4)            95.056633       301.85
#
#                                            min_players  std_players        cv  \
# name
#  Chinese PaladinSword and Fairy 5 Prequel         5.23    26.405695  0.439172
#  Fieldrunners 2                                   5.17    23.188083  1.576783
# #KILLALLZOMBIES                                   0.02    15.513927  2.080800
# #monstercakes                                     0.18    24.868169  0.630500
# (Chinese PaladinSword and Fairy 4)                0.34    57.258486  0.596091
#
#                                            total_months  growth_rate  \
# name
#  Chinese PaladinSword and Fairy 5 Prequel          97.0     0.269796
#  Fieldrunners 2                                   153.0    -0.006853
# #KILLALLZOMBIES                                    80.0     1.920467
# #monstercakes                                     102.0     0.858149
# (Chinese PaladinSword and Fairy 4)                 98.0     3.449732
#
#                                            peak_to_mean_ratio  \
# name
#  Chinese PaladinSword and Fairy 5 Prequel            2.355550
#  Fieldrunners 2                                     17.265803
# #KILLALLZOMBIES                                     14.248064
# #monstercakes                                        3.406524
# (Chinese PaladinSword and Fairy 4)                   3.142417
#
#                                            months_declining  \
# name
#  Chinese PaladinSword and Fairy 5 Prequel          0.536082
#  Fieldrunners 2                                    0.496732
# #KILLALLZOMBIES                                    0.475000
# #monstercakes                                      0.470588
# (Chinese PaladinSword and Fairy 4)                 0.510204
#
#                                            final_to_peak_ratio
# name
#  Chinese PaladinSword and Fairy 5 Prequel             0.344808
#  Fieldrunners 2                                       0.024244
# #KILLALLZOMBIES                                       0.014268
# #monstercakes                                         0.335476
# (Chinese PaladinSword and Fairy 4)                    0.259733

# %%
# filter out games with very low player counts to focus on meaningful patterns
game_features_filtered = game_features[game_features['mean_players'] >= 5].copy()
print(f"Filtered to {len(game_features_filtered)} games with mean >= 5 players")
# Out:
# Filtered to 3804 games with mean >= 5 players

# %%
# Standardize features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(game_features_filtered)

# elbow method to find optimal K
wcss = []
k_range = range(2,11)
for i in k_range:
    kmeans = KMeans(i)
    kmeans.fit(features_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(k_range, wcss, marker='o', linewidth=2)
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# use k=5 or k=6 clusters based on elbow
n_clusters = 6
kmeans = KMeans(n_clusters= n_clusters, init='k-means++', random_state=42)
game_features_filtered['cluster'] = kmeans.fit_predict(features_scaled)

print(f"Cluster distribution:")
print(game_features_filtered['cluster'].value_counts().sort_index())
# Out:
# Cluster distribution:
# cluster
# 0    1419
# 1       2
# 2     703
# 3      11
# 4     420
# 5    1249
# Name: count, dtype: int64

# %%
cluster_summary = game_features_filtered.groupby('cluster').agg({
    'mean_players': 'mean',
    'max_players': 'mean',
    'cv': 'mean',
    'growth_rate': 'mean',
    'months_declining': 'mean',
    'final_to_peak_ratio': 'mean',
    'total_months': 'mean'
}).round(2)

print("Cluster Characteristics:")
print(cluster_summary)
# Out:
# Cluster Characteristics:
#          mean_players  max_players    cv  growth_rate  months_declining  \
# cluster
# 0              406.10      1804.41  0.78         4.33              0.55
# 1           410055.05   1351202.08  0.74         0.09              0.47
# 2              972.63      2578.35  0.51        10.35              0.49
# 3            42386.56    136390.88  0.56         0.01              0.53
# 4              161.90      3141.44  2.51       170.94              0.56
# 5              269.75      1682.42  1.07        31.89              0.56
#
#          final_to_peak_ratio  total_months
# cluster
# 0                       0.12        138.11
# 1                       0.50        131.00
# 2                       0.54        119.36
# 3                       0.34        109.91
# 4                       0.02        107.35
# 5                       0.09         85.91

# %%
# visualize clusters in 2D (using PCA-like approach)
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
features_2d = pca.fit_transform(features_scaled)
scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], 
                     c=game_features_filtered['cluster'], cmap='viridis', 
                     alpha=0.6, s=50)
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
plt.title('Game Clusters Visualization (PCA)')
plt.colorbar(scatter, label='Cluster')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# show example games from each cluster
for cluster_id in range(n_clusters):
    print(f"\nCluster {cluster_id} - Top 5 games by avg players:")
    cluster_games = game_features_filtered[game_features_filtered['cluster'] == cluster_id]
    top_games = cluster_games.nlargest(5, 'mean_players')
    for idx, row in top_games.iterrows():
    print(f"  {idx}: {row['mean_players']:.0f} avg players")
# Out:
# Cluster 0 - Top 5 games by avg players:
#   ARK: Survival Evolved: 40965 avg players
#   Rocket League®: 29932 avg players
#   Unturned: 24082 avg players
#   Terraria: 23155 avg players
#   Path of Exile: 21192 avg players
#
# Cluster 1 - Top 5 games by avg players:
#   Counter-Strike 2: 471709 avg players
#   PUBG: BATTLEGROUNDS: 348401 avg players
#
# Cluster 2 - Top 5 games by avg players:
#   Wallpaper Engine: 40566 avg players
#   Warframe: 37252 avg players
#   Stardew Valley: 27869 avg players
#   War Thunder: 25249 avg players
#   Garry's Mod: 24833 avg players
#
# Cluster 3 - Top 5 games by avg players:
#   Grand Theft Auto V Legacy: 77629 avg players
#   HELLDIVERS™ 2: 67954 avg players
#   Team Fortress 2: 61088 avg players
#   Rust: 53738 avg players
#   Tom Clancy's Rainbow Six® Siege X: 52298 avg players
#
# Cluster 4 - Top 5 games by avg players:
#   Total War: THREE KINGDOMS: 7763 avg players
#   Z1 Battle Royale: 7481 avg players
#   Tom Clancy’s The Division™: 3014 avg players
#   Total War: WARHAMMER: 2973 avg players
#   METAL GEAR SOLID V: THE PHANTOM PAIN: 2547 avg players
#
# Cluster 5 - Top 5 games by avg players:
#   Mount & Blade II: Bannerlord: 17571 avg players
#   Satisfactory: 13804 avg players
#   Total War: WARHAMMER II: 11430 avg players
#   Paladins®: 10911 avg players
#   Victoria 3: 8160 avg players

# %% [markdown]
# # 2. Regression

# %% [markdown]
# ## Feature Engineering

# %%
# create lag features and rolling stats for each game
def create_prediction_features(group):
    group = group.sort_values('date').copy()
    
    # lag features
    for i in [1, 2, 3, 6]:
        group[f'avg_players_lag_{i}'] = group['avg_players'].shift(i)
        group[f'gain_lag_{i}'] = group['gain'].shift(i)
    
    # rolling statistics
    group['avg_players_roll_3'] = group['avg_players'].rolling(3, min_periods=1).mean()
    group['avg_players_roll_6'] = group['avg_players'].rolling(6, min_periods=1).mean()
    group['gain_roll_3'] = group['gain'].rolling(3, min_periods=1).mean()
    
    # trend features
    group['trend'] = group['avg_players'].pct_change()
    group['momentum'] = group['gain'].rolling(3, min_periods=1).mean()
    
    return group
df_features = df.groupby('steam_appid').apply(create_prediction_features).reset_index(drop=True)
print(f"Created features: {len(df_features)} records")
